# %% [markdown]
# ### Import Packages and Download Dataset

# %%
import kagglehub
import os
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV3Large

# %%
PATH = kagglehub.dataset_download("asefjamilajwad/car-crash-dataset-ccd")
print(PATH)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.3)
# C:\Users\Weiwei\.cache\kagglehub\datasets\asefjamilajwad\car-crash-dataset-ccd\versions\2

# %% [markdown]
# ### Load Data and Preprocessing

# %%
DATA_PATH = os.path.join(PATH, "CrashBest")
TABLE_PATH = os.path.join(PATH, "Crash_Table.csv")

TARGET_SIZE = (224, 224)

# %%
df = pd.read_csv(TABLE_PATH)
df.head()
# Out:
#    vidname  frame_1  frame_2  frame_3  ...  youtubeID  timing  weather  egoinvolve
# 0        1        0        0        0  ...          0     Day   Normal         Yes
# 1        2        0        0        0  ...          0     Day   Normal         Yes
# 2        3        0        0        0  ...          0     Day   Normal         Yes
# 3        4        0        0        0  ...          0     Day   Normal         Yes
# 4        5        0        0        0  ...         10     Day    Snowy         Yes
#
# [5 rows x 56 columns]

# %%
df_sampled = df.sample(100, random_state=40)

# %%
def get_file_name(video_name, frame_name):
  return f"C_{video_name:06}_{frame_name:02}.jpg"

def get_video_frame_paths(video_name):
  frame_paths = []
  for i in range (1, 51):
    frame_path = os.path.join(DATA_PATH, get_file_name(video_name, i))
    frame_paths.append(frame_path)
  return frame_paths

# %%
video_names = []
raw_images =[]
labels = []
timings = []

for idx, row in df_sampled.iterrows():
  frame_paths = get_video_frame_paths(row["vidname"])
  if all(os.path.exists(frame_path) for frame_path in frame_paths):
    for frame_path in frame_paths:
      image = cv2.imread(frame_path)
      image = cv2.resize(image, TARGET_SIZE)
      raw_images.append(image)
      
    for i in range(1, 51):
      labels.append(row[f"frame_{i}"])
      timings.append(row["timing"])
      video_names.append(row["vidname"])

print("Length of video_names: ", len(video_names))
print("Length of image_paths: ", len(raw_images))
print("Length of labels: ", len(labels))
print("Length of timings: ", len(timings))
# Out:
# Length of video_names:  5000
# Length of image_paths:  5000
# Length of labels:  5000
# Length of timings:  5000

# %%
x_train, x_temp, y_train, y_temp = train_test_split(raw_images, labels, test_size=0.2, random_state=40)
x_test, x_val, y_test, y_val = train_test_split(x_temp, y_temp, test_size=0.5, random_state=40)

# %%
model = MobileNetV3Large(include_top=False, input_shape=(224, 224, 3))
for layer in model.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 [==============================] - 2s 0us/step

# %%
x = model.output
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(50, activation='relu')(x)
output_layer = tf.keras.layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.models.Model(inputs=model.input, outputs=output_layer)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling_1 (Rescaling)        (None, 224, 224, 3)  0           ['input_2[0][0]']
#
#  Conv (Conv2D)                  (None, 112, 112, 16  432         ['rescaling_1[0][0]']
#                                 )
#
#  Conv/BatchNorm (BatchNormaliza  (None, 112, 112, 16  64         ['Conv[0][0]']
#  tion)                          )
#
#  tf.__operators__.add_27 (TFOpL  (None, 112, 112, 16  0          ['Conv/BatchNorm[0][0]']
#  ambda)                         )
#
#  re_lu_32 (ReLU)                (None, 112, 112, 16  0           ['tf.__operators__.add_27[0][0]']
#                                 )
#
#  tf.math.multiply_27 (TFOpLambd  (None, 112, 112, 16  0          ['re_lu_32[0][0]']
#  a)                             )
#
#  multiply_18 (Multiply)         (None, 112, 112, 16  0           ['Conv/BatchNorm[0][0]',
#                                 )                                 'tf.math.multiply_27[0][0]']
#
#  expanded_conv/depthwise (Depth  (None, 112, 112, 16  144        ['multiply_18[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv/depthwise/BatchN  (None, 112, 112, 16  64         ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)       )
#
#  re_lu_33 (ReLU)                (None, 112, 112, 16  0           ['expanded_conv/depthwise/BatchNo
#                                 )                                rm[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 112, 112, 16  256        ['re_lu_33[0][0]']
#                                 )
#
#  expanded_conv/project/BatchNor  (None, 112, 112, 16  64         ['expanded_conv/project[0][0]']
#  m (BatchNormalization)         )
#
#  expanded_conv/Add (Add)        (None, 112, 112, 16  0           ['multiply_18[0][0]',
#                                 )                                 'expanded_conv/project/BatchNorm
#                                                                  [0][0]']
#
#  expanded_conv_1/expand (Conv2D  (None, 112, 112, 64  1024       ['expanded_conv/Add[0][0]']
#  )                              )
#
#  expanded_conv_1/expand/BatchNo  (None, 112, 112, 64  256        ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)        )
#
#  re_lu_34 (ReLU)                (None, 112, 112, 64  0           ['expanded_conv_1/expand/BatchNor
#                                 )                                m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 113, 113, 64  0          ['re_lu_34[0][0]']
#  (ZeroPadding2D)                )
#
#  expanded_conv_1/depthwise (Dep  (None, 56, 56, 64)  576         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 56, 56, 64)  256         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_35 (ReLU)                (None, 56, 56, 64)   0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 56, 56, 24)  1536        ['re_lu_35[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 56, 56, 24)  96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 56, 56, 72)  1728        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 56, 56, 72)  288         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_36 (ReLU)                (None, 56, 56, 72)   0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 56, 56, 72)  648         ['re_lu_36[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 56, 56, 72)  288         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_37 (ReLU)                (None, 56, 56, 72)   0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 56, 56, 24)  1728        ['re_lu_37[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 56, 56, 24)  96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 56, 56, 24)   0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 56, 56, 72)  1728        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 56, 56, 72)  288         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_38 (ReLU)                (None, 56, 56, 72)   0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 59, 59, 72)  0           ['re_lu_38[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 28, 28, 72)  1800        ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 28, 28, 72)  288         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_39 (ReLU)                (None, 28, 28, 72)   0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    0           ['re_lu_39[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    1752        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    1800        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_28 (TFOpL  (None, 1, 1, 72)    0           ['expanded_conv_3/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_40 (ReLU)                (None, 1, 1, 72)     0           ['tf.__operators__.add_28[0][0]']
#
#  tf.math.multiply_28 (TFOpLambd  (None, 1, 1, 72)    0           ['re_lu_40[0][0]']
#  a)
#
#  expanded_conv_3/squeeze_excite  (None, 28, 28, 72)  0           ['re_lu_39[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_28[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 28, 28, 40)  2880        ['expanded_conv_3/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, 28, 28, 40)  160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 28, 28, 120)  4800       ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 28, 28, 120)  480        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_41 (ReLU)                (None, 28, 28, 120)  0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 28, 28, 120)  3000       ['re_lu_41[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 28, 28, 120)  480        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_42 (ReLU)                (None, 28, 28, 120)  0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_42[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_29 (TFOpL  (None, 1, 1, 120)   0           ['expanded_conv_4/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_43 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_29[0][0]']
#
#  tf.math.multiply_29 (TFOpLambd  (None, 1, 1, 120)   0           ['re_lu_43[0][0]']
#  a)
#
#  expanded_conv_4/squeeze_excite  (None, 28, 28, 120)  0          ['re_lu_42[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_29[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 28, 28, 40)  4800        ['expanded_conv_4/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, 28, 28, 40)  160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 28, 28, 40)   0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 28, 28, 120)  4800       ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 28, 28, 120)  480        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_44 (ReLU)                (None, 28, 28, 120)  0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 28, 28, 120)  3000       ['re_lu_44[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 28, 28, 120)  480        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_45 (ReLU)                (None, 28, 28, 120)  0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_45[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_30 (TFOpL  (None, 1, 1, 120)   0           ['expanded_conv_5/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_46 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_30[0][0]']
#
#  tf.math.multiply_30 (TFOpLambd  (None, 1, 1, 120)   0           ['re_lu_46[0][0]']
#  a)
#
#  expanded_conv_5/squeeze_excite  (None, 28, 28, 120)  0          ['re_lu_45[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_30[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 28, 28, 40)  4800        ['expanded_conv_5/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, 28, 28, 40)  160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 28, 28, 40)   0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 28, 28, 240)  9600       ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 28, 28, 240)  960        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_31 (TFOpL  (None, 28, 28, 240)  0          ['expanded_conv_6/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_47 (ReLU)                (None, 28, 28, 240)  0           ['tf.__operators__.add_31[0][0]']
#
#  tf.math.multiply_31 (TFOpLambd  (None, 28, 28, 240)  0          ['re_lu_47[0][0]']
#  a)
#
#  multiply_19 (Multiply)         (None, 28, 28, 240)  0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_31[0][0]']
#
#  expanded_conv_6/depthwise/pad   (None, 29, 29, 240)  0          ['multiply_19[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_6/depthwise (Dep  (None, 14, 14, 240)  2160       ['expanded_conv_6/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_6/depthwise/Batc  (None, 14, 14, 240)  960        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_32 (TFOpL  (None, 14, 14, 240)  0          ['expanded_conv_6/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_48 (ReLU)                (None, 14, 14, 240)  0           ['tf.__operators__.add_32[0][0]']
#
#  tf.math.multiply_32 (TFOpLambd  (None, 14, 14, 240)  0          ['re_lu_48[0][0]']
#  a)
#
#  multiply_20 (Multiply)         (None, 14, 14, 240)  0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_32[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 14, 14, 80)  19200       ['multiply_20[0][0]']
#  D)
#
#  expanded_conv_6/project/BatchN  (None, 14, 14, 80)  320         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 14, 14, 200)  16000      ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 14, 14, 200)  800        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_33 (TFOpL  (None, 14, 14, 200)  0          ['expanded_conv_7/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_49 (ReLU)                (None, 14, 14, 200)  0           ['tf.__operators__.add_33[0][0]']
#
#  tf.math.multiply_33 (TFOpLambd  (None, 14, 14, 200)  0          ['re_lu_49[0][0]']
#  a)
#
#  multiply_21 (Multiply)         (None, 14, 14, 200)  0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_33[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 14, 14, 200)  1800       ['multiply_21[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 14, 14, 200)  800        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_34 (TFOpL  (None, 14, 14, 200)  0          ['expanded_conv_7/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_50 (ReLU)                (None, 14, 14, 200)  0           ['tf.__operators__.add_34[0][0]']
#
#  tf.math.multiply_34 (TFOpLambd  (None, 14, 14, 200)  0          ['re_lu_50[0][0]']
#  a)
#
#  multiply_22 (Multiply)         (None, 14, 14, 200)  0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_34[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 14, 14, 80)  16000       ['multiply_22[0][0]']
#  D)
#
#  expanded_conv_7/project/BatchN  (None, 14, 14, 80)  320         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 14, 14, 80)   0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 14, 14, 184)  14720      ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 14, 14, 184)  736        ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_35 (TFOpL  (None, 14, 14, 184)  0          ['expanded_conv_8/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_51 (ReLU)                (None, 14, 14, 184)  0           ['tf.__operators__.add_35[0][0]']
#
#  tf.math.multiply_35 (TFOpLambd  (None, 14, 14, 184)  0          ['re_lu_51[0][0]']
#  a)
#
#  multiply_23 (Multiply)         (None, 14, 14, 184)  0           ['expanded_conv_8/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_35[0][0]']
#
#  expanded_conv_8/depthwise (Dep  (None, 14, 14, 184)  1656       ['multiply_23[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_8/depthwise/Batc  (None, 14, 14, 184)  736        ['expanded_conv_8/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_36 (TFOpL  (None, 14, 14, 184)  0          ['expanded_conv_8/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_52 (ReLU)                (None, 14, 14, 184)  0           ['tf.__operators__.add_36[0][0]']
#
#  tf.math.multiply_36 (TFOpLambd  (None, 14, 14, 184)  0          ['re_lu_52[0][0]']
#  a)
#
#  multiply_24 (Multiply)         (None, 14, 14, 184)  0           ['expanded_conv_8/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_36[0][0]']
#
#  expanded_conv_8/project (Conv2  (None, 14, 14, 80)  14720       ['multiply_24[0][0]']
#  D)
#
#  expanded_conv_8/project/BatchN  (None, 14, 14, 80)  320         ['expanded_conv_8/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_8/Add (Add)      (None, 14, 14, 80)   0           ['expanded_conv_7/Add[0][0]',
#                                                                   'expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_9/expand (Conv2D  (None, 14, 14, 184)  14720      ['expanded_conv_8/Add[0][0]']
#  )
#
#  expanded_conv_9/expand/BatchNo  (None, 14, 14, 184)  736        ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_37 (TFOpL  (None, 14, 14, 184)  0          ['expanded_conv_9/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_53 (ReLU)                (None, 14, 14, 184)  0           ['tf.__operators__.add_37[0][0]']
#
#  tf.math.multiply_37 (TFOpLambd  (None, 14, 14, 184)  0          ['re_lu_53[0][0]']
#  a)
#
#  multiply_25 (Multiply)         (None, 14, 14, 184)  0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_37[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 14, 14, 184)  1656       ['multiply_25[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 14, 14, 184)  736        ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_38 (TFOpL  (None, 14, 14, 184)  0          ['expanded_conv_9/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_54 (ReLU)                (None, 14, 14, 184)  0           ['tf.__operators__.add_38[0][0]']
#
#  tf.math.multiply_38 (TFOpLambd  (None, 14, 14, 184)  0          ['re_lu_54[0][0]']
#  a)
#
#  multiply_26 (Multiply)         (None, 14, 14, 184)  0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_38[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 14, 14, 80)  14720       ['multiply_26[0][0]']
#  D)
#
#  expanded_conv_9/project/BatchN  (None, 14, 14, 80)  320         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 14, 14, 80)   0           ['expanded_conv_8/Add[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 14, 14, 480)  38400      ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 14, 14, 480)  1920       ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_39 (TFOpL  (None, 14, 14, 480)  0          ['expanded_conv_10/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_55 (ReLU)                (None, 14, 14, 480)  0           ['tf.__operators__.add_39[0][0]']
#
#  tf.math.multiply_39 (TFOpLambd  (None, 14, 14, 480)  0          ['re_lu_55[0][0]']
#  a)
#
#  multiply_27 (Multiply)         (None, 14, 14, 480)  0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_39[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 14, 14, 480)  4320       ['multiply_27[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 14, 14, 480)  1920       ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_40 (TFOpL  (None, 14, 14, 480)  0          ['expanded_conv_10/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_56 (ReLU)                (None, 14, 14, 480)  0           ['tf.__operators__.add_40[0][0]']
#
#  tf.math.multiply_40 (TFOpLambd  (None, 14, 14, 480)  0          ['re_lu_56[0][0]']
#  a)
#
#  multiply_28 (Multiply)         (None, 14, 14, 480)  0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_40[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 480)   0           ['multiply_28[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 120)   57720       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
# ...
#
#  tf.__operators__.add_48 (TFOpL  (None, 7, 7, 960)   0           ['expanded_conv_13/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_64 (ReLU)                (None, 7, 7, 960)    0           ['tf.__operators__.add_48[0][0]']
#
#  tf.math.multiply_48 (TFOpLambd  (None, 7, 7, 960)   0           ['re_lu_64[0][0]']
#  a)
#
#  multiply_33 (Multiply)         (None, 7, 7, 960)    0           ['expanded_conv_13/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_48[0][0]']
#
#  expanded_conv_13/depthwise (De  (None, 7, 7, 960)   24000       ['multiply_33[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_13/depthwise/Bat  (None, 7, 7, 960)   3840        ['expanded_conv_13/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_49 (TFOpL  (None, 7, 7, 960)   0           ['expanded_conv_13/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_65 (ReLU)                (None, 7, 7, 960)    0           ['tf.__operators__.add_49[0][0]']
#
#  tf.math.multiply_49 (TFOpLambd  (None, 7, 7, 960)   0           ['re_lu_65[0][0]']
#  a)
#
#  multiply_34 (Multiply)         (None, 7, 7, 960)    0           ['expanded_conv_13/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_49[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_34[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 240)   230640      ['expanded_conv_13/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 240)   0           ['expanded_conv_13/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   231360      ['expanded_conv_13/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_50 (TFOpL  (None, 1, 1, 960)   0           ['expanded_conv_13/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_66 (ReLU)                (None, 1, 1, 960)    0           ['tf.__operators__.add_50[0][0]']
#
#  tf.math.multiply_50 (TFOpLambd  (None, 1, 1, 960)   0           ['re_lu_66[0][0]']
#  a)
#
#  expanded_conv_13/squeeze_excit  (None, 7, 7, 960)   0           ['multiply_34[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_50[0][0]']
#
#  expanded_conv_13/project (Conv  (None, 7, 7, 160)   153600      ['expanded_conv_13/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_13/project/Batch  (None, 7, 7, 160)   640         ['expanded_conv_13/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_13/Add (Add)     (None, 7, 7, 160)    0           ['expanded_conv_12/project/BatchN
#                                                                  orm[0][0]',
#                                                                   'expanded_conv_13/project/BatchN
#                                                                  orm[0][0]']
#
#  expanded_conv_14/expand (Conv2  (None, 7, 7, 960)   153600      ['expanded_conv_13/Add[0][0]']
#  D)
#
#  expanded_conv_14/expand/BatchN  (None, 7, 7, 960)   3840        ['expanded_conv_14/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_51 (TFOpL  (None, 7, 7, 960)   0           ['expanded_conv_14/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_67 (ReLU)                (None, 7, 7, 960)    0           ['tf.__operators__.add_51[0][0]']
#
#  tf.math.multiply_51 (TFOpLambd  (None, 7, 7, 960)   0           ['re_lu_67[0][0]']
#  a)
#
#  multiply_35 (Multiply)         (None, 7, 7, 960)    0           ['expanded_conv_14/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_51[0][0]']
#
#  expanded_conv_14/depthwise (De  (None, 7, 7, 960)   24000       ['multiply_35[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_14/depthwise/Bat  (None, 7, 7, 960)   3840        ['expanded_conv_14/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_52 (TFOpL  (None, 7, 7, 960)   0           ['expanded_conv_14/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_68 (ReLU)                (None, 7, 7, 960)    0           ['tf.__operators__.add_52[0][0]']
#
#  tf.math.multiply_52 (TFOpLambd  (None, 7, 7, 960)   0           ['re_lu_68[0][0]']
#  a)
#
#  multiply_36 (Multiply)         (None, 7, 7, 960)    0           ['expanded_conv_14/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_52[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_36[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 240)   230640      ['expanded_conv_14/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 240)   0           ['expanded_conv_14/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   231360      ['expanded_conv_14/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_53 (TFOpL  (None, 1, 1, 960)   0           ['expanded_conv_14/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_69 (ReLU)                (None, 1, 1, 960)    0           ['tf.__operators__.add_53[0][0]']
#
#  tf.math.multiply_53 (TFOpLambd  (None, 1, 1, 960)   0           ['re_lu_69[0][0]']
#  a)
#
#  expanded_conv_14/squeeze_excit  (None, 7, 7, 960)   0           ['multiply_36[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_53[0][0]']
#
#  expanded_conv_14/project (Conv  (None, 7, 7, 160)   153600      ['expanded_conv_14/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_14/project/Batch  (None, 7, 7, 160)   640         ['expanded_conv_14/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_14/Add (Add)     (None, 7, 7, 160)    0           ['expanded_conv_13/Add[0][0]',
#                                                                   'expanded_conv_14/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 7, 7, 960)    153600      ['expanded_conv_14/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 7, 7, 960)   3840        ['Conv_1[0][0]']
#  zation)
#
#  tf.__operators__.add_54 (TFOpL  (None, 7, 7, 960)   0           ['Conv_1/BatchNorm[0][0]']
#  ambda)
#
#  re_lu_70 (ReLU)                (None, 7, 7, 960)    0           ['tf.__operators__.add_54[0][0]']
#
#  tf.math.multiply_54 (TFOpLambd  (None, 7, 7, 960)   0           ['re_lu_70[0][0]']
#  a)
#
#  multiply_37 (Multiply)         (None, 7, 7, 960)    0           ['Conv_1/BatchNorm[0][0]',
#                                                                   'tf.math.multiply_54[0][0]']
#
#  flatten_1 (Flatten)            (None, 47040)        0           ['multiply_37[0][0]']
#
#  dense_2 (Dense)                (None, 50)           2352050     ['flatten_1[0][0]']
#
#  dense_3 (Dense)                (None, 1)            51          ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 5,348,453
# Trainable params: 2,352,101
# Non-trainable params: 2,996,352
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
EPOCHS = 10
BATCH_SIZE = 32

# %%
history = model.fit(np.array(x_train), np.array(y_train), epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(np.array(x_val), np.array(y_val)))
# Out:
# Epoch 1/10
# 125/125 [==============================] - 60s 444ms/step - loss: 0.7686 - accuracy: 0.8495 - val_loss: 0.3309 - val_accuracy: 0.8900
# Epoch 2/10
# 125/125 [==============================] - 51s 409ms/step - loss: 0.1224 - accuracy: 0.9597 - val_loss: 0.1396 - val_accuracy: 0.9420
# Epoch 3/10
# 125/125 [==============================] - 53s 425ms/step - loss: 0.0926 - accuracy: 0.9737 - val_loss: 0.1628 - val_accuracy: 0.9500
# Epoch 4/10
# 125/125 [==============================] - 50s 403ms/step - loss: 0.0413 - accuracy: 0.9868 - val_loss: 0.1419 - val_accuracy: 0.9540
# Epoch 5/10
# 125/125 [==============================] - 50s 399ms/step - loss: 0.0356 - accuracy: 0.9893 - val_loss: 0.1526 - val_accuracy: 0.9540
# Epoch 6/10
# 125/125 [==============================] - 52s 412ms/step - loss: 0.0369 - accuracy: 0.9898 - val_loss: 0.1276 - val_accuracy: 0.9600
# Epoch 7/10
# 125/125 [==============================] - 53s 423ms/step - loss: 0.0162 - accuracy: 0.9962 - val_loss: 0.1228 - val_accuracy: 0.9580
# Epoch 8/10
# 125/125 [==============================] - 54s 430ms/step - loss: 0.0179 - accuracy: 0.9955 - val_loss: 0.1159 - val_accuracy: 0.9720
# Epoch 9/10
# 125/125 [==============================] - 53s 422ms/step - loss: 0.0204 - accuracy: 0.9950 - val_loss: 0.1470 - val_accuracy: 0.9600
# Epoch 10/10
# 125/125 [==============================] - 52s 419ms/step - loss: 0.0147 - accuracy: 0.9960 - val_loss: 0.1086 - val_accuracy: 0.9680

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend(loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend(loc='upper right')
plt.show()

# %%
test_loss, test_acc = model.evaluate(np.array(x_test), np.array(y_test), verbose=2)

print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# 16/16 - 5s - loss: 0.1381 - accuracy: 0.9620 - 5s/epoch - 325ms/step
# Test accuracy: 0.9620000123977661
# Test loss: 0.1380988210439682

# %%
y_pred = model.predict(np.array(x_test))
y_pred = np.round(y_pred)

print("True Labels vs. Predicted Labels:")
for i in range(10):
  print(f"True Label: {int(y_test[i])}, Predicted Label: {int(y_pred[i])}")
# Out:
# 16/16 [==============================] - 7s 349ms/step
# True Labels vs. Predicted Labels:
# True Label: 0, Predicted Label: 0
# True Label: 0, Predicted Label: 1
# True Label: 1, Predicted Label: 1
# True Label: 0, Predicted Label: 0
# True Label: 0, Predicted Label: 0
# True Label: 0, Predicted Label: 0
# True Label: 0, Predicted Label: 0
# True Label: 0, Predicted Label: 0
# True Label: 0, Predicted Label: 0
# True Label: 1, Predicted Label: 1

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       358
#            1       0.96      0.90      0.93       142
#
#     accuracy                           0.96       500
#    macro avg       0.96      0.94      0.95       500
# weighted avg       0.96      0.96      0.96       500

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
model.save('models/mobilenetv3.keras')
